# %% [markdown]
# # EMNIST

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import layers, models
from emnist import extract_training_samples,extract_test_samples
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
# # Load EMNIST dataset
train_images, train_labels = extract_training_samples('bymerge')
test_images, test_labels = extract_test_samples('bymerge')

# %% [markdown]
# #### Lable mapping

# %% [markdown]
# - Keeping only 3 classes 'A', 'B' and 'C' from the alphabets

# %%
# Identify the labels you want to keep (first 36 classes)
valid_labels = set(range(13))

def filter_data(data,labels):
    # Filter the labels and corresponding data
    filtered_indices = [i for i, label in enumerate(labels) if label in valid_labels]
    filtered_labels = labels[filtered_indices]
    # Assuming emnist_data is your array of corresponding data
    filtered_data = data[filtered_indices]
    return filtered_data, filtered_labels

# %%
train_images, train_labels = filter_data(train_images, train_labels)
test_images, test_labels = filter_data(test_images, test_labels)
# # Saving filtered data locally
# np.save('emnist36_train.npy', train_images)
# np.save('emnist36_train_labels.npy', train_labels)
# np.save('emnist36_test.npy', test_images)
# np.save('emnist36_test_labels.npy', test_labels)

# %%
# Display some random images from the training set
plt.figure(figsize=(10, 10))
for i in range(30):
    plt.subplot(5, 6, i + 1)
    plt.imshow(train_images[i], cmap='gray')
    plt.title(f"Label: {train_labels[i]}")
    plt.axis('off')
plt.show()

# %%
# One-hot encode the labels
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %% [markdown]
# - Taking a small random batch of emnist data

# %%
# Extract a batch of data
batch_size = 1000
# Set the seed for reproducibility
np.random.seed(128)
# Randomly shuffle the indices
indices = np.random.permutation(len(train_images))
selected_indices = indices[:batch_size]
# Extract images and labels based on selected indices
train_images_batch = train_images[selected_indices]
train_labels_batch = train_labels[selected_indices]

"""
~ Additional step: Reduce the batch size but make sure that all samples are included atleast ~N times
"""
# Out:
# '\n~ Additional step: Reduce the batch size but make sure that all samples are included atleast ~N times\n'

# %%
# Build the model
model = models.Sequential()
model.add(layers.Flatten(input_shape=(28, 28)))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(13, activation='softmax'))

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model on the MNIST dataset
model.fit(train_images_batch, train_labels_batch, epochs=20, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/20
# 25/25 [==============================] - 1s 10ms/step - loss: 22.5628 - accuracy: 0.4250 - val_loss: 7.4888 - val_accuracy: 0.6550
# Epoch 2/20
# 25/25 [==============================] - 0s 4ms/step - loss: 3.9821 - accuracy: 0.7487 - val_loss: 5.4946 - val_accuracy: 0.6650
# Epoch 3/20
# 25/25 [==============================] - 0s 4ms/step - loss: 1.2011 - accuracy: 0.8637 - val_loss: 5.1522 - val_accuracy: 0.7000
# Epoch 4/20
# 25/25 [==============================] - 0s 5ms/step - loss: 0.5004 - accuracy: 0.9212 - val_loss: 4.9509 - val_accuracy: 0.6650
# Epoch 5/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1925 - accuracy: 0.9563 - val_loss: 4.3466 - val_accuracy: 0.7450
# Epoch 6/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0558 - accuracy: 0.9825 - val_loss: 4.0232 - val_accuracy: 0.7450
# Epoch 7/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0669 - accuracy: 0.9862 - val_loss: 4.2435 - val_accuracy: 0.7350
# Epoch 8/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0561 - accuracy: 0.9837 - val_loss: 3.9921 - val_accuracy: 0.7400
# Epoch 9/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0584 - accuracy: 0.9900 - val_loss: 4.2439 - val_accuracy: 0.7650
# Epoch 10/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0235 - accuracy: 0.9937 - val_loss: 4.1294 - val_accuracy: 0.8100
# Epoch 11/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0116 - accuracy: 0.9975 - val_loss: 4.1946 - val_accuracy: 0.7650
# Epoch 12/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0328 - accuracy: 0.9900 - val_loss: 4.2431 - val_accuracy: 0.7650
# Epoch 13/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 0.9937 - val_loss: 4.4350 - val_accuracy: 0.7950
# Epoch 14/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0269 - accuracy: 0.9925 - val_loss: 4.1554 - val_accuracy: 0.7700
# Epoch 15/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0980 - accuracy: 0.9825 - val_loss: 4.5780 - val_accuracy: 0.7800
# Epoch 16/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2025 - accuracy: 0.9663 - val_loss: 4.7133 - val_accuracy: 0.7350
# Epoch 17/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4086 - accuracy: 0.9475 - val_loss: 4.3964 - val_accuracy: 0.7600
# Epoch 18/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4394 - accuracy: 0.9413 - val_loss: 4.5707 - val_accuracy: 0.8000
# Epoch 19/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.7278 - accuracy: 0.9337 - val_loss: 5.2420 - val_accuracy: 0.7400
# Epoch 20/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4874 - accuracy: 0.9475 - val_loss: 4.8244 - val_accuracy: 0.8100

# %%
# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {round(test_acc*100,2)} %')
# Out:
# 1919/1919 [==============================] - 3s 1ms/step - loss: 4.2309 - accuracy: 0.8021
# Test accuracy: 80.21 %

# %%
test_label_predict = model.predict(test_images)
test_label_predict = tf.argmax(test_label_predict, axis=1).numpy()
# Out:
# 1919/1919 [==============================] - 2s 1ms/step

# %% [markdown]
# - Mapping labels for visualization clarity

# %%
"""
Working on mapping
"""
# Assuming emnist_labels is the array of original labels
# emnist_labels = np.array([0, 1, 2, ..., 45, 46])

# Define a mapping for digits and alphabets
digit_mapping = {i: str(i) for i in range(10)}
alphabet_mapping = {i: chr(i + 55) for i in range(10,47)}  # ASCII code for 'A' is 65, so we use 55 to map to 11

# Apply the mapping to the labels
mapped_labels = np.array([digit_mapping[label] if label < 10 else alphabet_mapping[label] for label in test_label_predict])

# %%
import random
# Generate 9 random numbers between 0 and 20800
random_numbers = random.sample(range(20800), 25)

# %%
# Display some random images from the training set
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.imshow(test_images[i], cmap='gray')
    plt.title(f"Label: {mapped_labels[i]}") 
    plt.axis('off')
    plt.suptitle('Model prediction with {} % Accuracy (EMNIST), with TL model'.format(round((test_acc*100),2)))
plt.show()
